# %%
#riya natekar Expp1:introduction to python

# %%
x,y,z="orange","apple","banana"
print(x)
# Out:
# orange

# %%
x,y,z,w = "orange","apple","banana","mango"
print(x)
print(y)
print(z)
print(w)
# Out:
# orange
# apple
# banana
# mango

# %%
#how to fnd data types

x=2
y=2.5
z="riya"
w=True
print(type(x))
print(type(x))
print(type(z))
print(type(w))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>

# %%
x=10
y=5
add=x+y
sub=x-y
mul=x*y
div=x/y
exp=x**y
print(add)
print(sub)
print(mul)
print(div)
print(exp)
# Out:
# 15
# 5
# 50
# 2.0
# 100000

# %%
x,y=10,5
print("add =",x+y)
print("sub =",x-y)
print("mul =",x*y)
print("div =",x/y)
print("exp =",x**y)
# Out:
# add = 15
# sub = 5
# mul = 50
# div = 2.0
# exp = 100000

# %%
#generalise input

x=int(input("enter the value of x="))
y=int(input("enter the value of y="))
print("add =",x+y)
print("sub =",x-y)
print("mul =",x*y)
print("div =",x/y)
print("exp =",x**y)
# Out:
# enter the value of x=6
# enter the value of y=9
# add = 15
# sub = -3
# mul = 54
# div = 0.6666666666666666
# exp = 10077696

# %%
r=int(input("enter the value of radius:"))
area=3.14*r**2
print(area)
# Out:
# enter the value of radius:8
# 200.96

# %%
r=float(input("enter the radius: "))
import math
area= (math.pi)*r**2
print(area)
# Out:
# enter the radius: 4
# 50.26548245743669

# %%
import math
print(math.log10(10))
# Out:
# 1.0

# %%
#find greater number

a=int(input("enter the value of a:"))
b=int(input("enter the value of b:"))
if a>b:
    print("a is greater")
else:
    print("b is greater")
# Out:
# enter the value of a:5
# enter the value of b:3
# a is greater
